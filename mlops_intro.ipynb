# %% [markdown]
# ### DevOps/MLOps

# %% [markdown]
# `SDLC`
#
# 1. Planning & Requirement gaethering
# 2. Define the Architecture of the project
# 3. Project building (development)
# 4. Testing
# 5. Deployment
#
#
# `Types of SDLC`
# 1. **Waterfall**
#
# ![image.png](attachment:image.png)
#
# In Waterfall way, we can not jump stages.. we have to follow the hierarchy like first we will gather all requirements, then design then development & so on. we can not start development until requirement & design is finished!! This was the old method which was used.
#
# 2. **Agile**
#
# ![image-2.png](attachment:image-2.png)
#
# In Agile way, we are doing everything in iteration.
#
# **Example**
# - The `Arogya Setu` app was developed to collect user information and provide real-time analysis to help track and inform individuals diagnosed with COVID-19. The government contracted XYZ company to build the app, which initially planned to use the traditional waterfall methodology.
#
# - According to the waterfall approach, the project would follow a linear sequence: planning, designing, development, testing, and then deployment. XYZ company estimated a timeline of 8-10 months to complete the app. However, given the urgent need for a solution to combat the ongoing COVID-19 pandemic, a timeline of 8-10 months was deemed unrealistic. Delaying the app's launch by that long would have rendered the project ineffective and the contract at risk.
#
# - In response to this challenge, XYZ company proposed switching to an Agile methodology. By adopting Agile, the app could be developed and launched in shorter iterations, allowing for faster deployment of initial features. In the first iteration, the app was designed to collect user information and provide basic guidelines. Subsequent iterations would then focus on adding more advanced features, such as identifying nearby individuals who have tested positive for COVID-19, along with other functionalities.
#
# - In the first iteration, all phases of Agile (planning, design, development, testing, and deployment) were completed successfully, and the app was launched. Moving forward, XYZ will continue to enhance the app, adding new features, testing, and deploying them iteratively, ensuring that the app evolves in real-time to meet users' needs.

# %% [markdown]
# `DevOps`
#
# 1. `Deveopment`: development, testing, qa
# 2. `Ops`: delivery, deployment, maintanance & monitoring
#
# - Earlier we were executing everything manually, after developing sending code file to testing team for QA. after that sending to deployment team. Sometime application gives error when we share code files with different team to test or deploy. In order to automate the entire manual process and fix the environment issue, `DevOps Engineer` post was created who knows about all steps & tools used for development & operations except writing development codes.
#
# 1. Git/Github: to manage the source code
# 2. Docker for delivery & Kubernetes for managing docker
# 3. Jenkins/Github actions/Circle CI/ Traviz CI  to automate testing & deployment
# 4. Teraform to automate server creation and so on..

# %% [markdown]
# `MLOps`
#
#
# **Development**
#
# 1. Machine Learning (ML): Development
# - Data wrangling
# - Data Assesment
# - Data Cleaning
# - EDA
# - Feature Engineering
# - Model Building
# - Model Evaluation
#
# 2. Ops (Operations): Deployment
# - Deployment
# - Monitoring/Re-training

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - Machine Learning (ML) and Deep Learning (DL) development differ significantly from traditional software development.
#
# - In traditional software development, the focus is primarily on writing frontend and backend scripts and integrating databases to create functional applications. The process typically involves designing user interfaces, implementing business logic, and setting up databases for data storage and retrieval.
#
# - On the other hand, ML/DL development is centered around a different workflow. The core steps in ML/DL development include:
#
#     1. Data Collection: Gathering large volumes of data relevant to the problem you're trying to solve.
#     2. Data Preprocessing: Cleaning and transforming the data to make it suitable for training the model.
#     3. Feature Engineering: Creating new features from the data that can improve the model's performance.
#     4. Model Training: Using algorithms to train the model on the data, learning patterns and relationships.
#     5. Model Evaluation: Assessing the model's performance using appropriate metrics and techniques, such as cross-validation, accuracy, precision, recall, etc.
#     6. Model Optimization: Fine-tuning the model to improve accuracy and efficiency, often through techniques like hyperparameter tuning.
#
# - Unlike traditional software development, where the goal is to create a static, predefined application, ML/DL development requires iterative refinement and constant evaluation of models to ensure they generalize well on unseen data. It’s more about learning from data and adjusting the system based on performance metrics.

# %% [markdown]
# ### CI (Continuous Integration) & CD (Continuous Deployment)
#
# - CI (Continuous Integration): Developers continuously push code changes to a shared repository. Each time code is pushed, automated tests run to check for issues in different environments. This ensures the main application remains stable and doesn't break. We can use tools like github actions, circle ci etc
#
# - CD (Continuous Deployment): After successful tests in the CI pipeline, the code is automatically pushed to the main application or production environment. This step ensures that updates are deployed quickly and reliably once they pass all checks.

# %% [markdown]
# ### Git & GitHub
#
# - For Source code management

# %% [markdown]
# ### Docker
#
# - What is docker?
# - How does it work?
# - Docker engine
# - Docker contianer VS VM
# - Docker file
# - Docker Image
# - Docker Command
# - Port mapping
# - Docker networking
# - Docker volume
# - Docker compose

# %% [markdown]
# - `Docker` is an open-source tool created by Solomon Hykes in 2013.
# - `Virtualization` in Docker is handled by the Docker Engine, which is written in Go and runs on Linux-based systems.
#
# **`Types of Services`**
# There are three primary types of cloud services:
#
# 1. IAAS (Infrastructure as a Service): Provides virtualized computing resources over the internet (e.g., AWS EC2).
# 2. PAAS (Platform as a Service): Provides a platform allowing customers to develop, run, and manage applications without worrying about the underlying hardware or software (e.g., Heroku, Google App Engine).
# 3. SAAS (Software as a Service): Provides software applications over the internet, usually on a subscription basis (e.g., Gmail, Dropbox).
#
# - Docker falls under PAAS because it provides a platform to build, run, and deploy applications efficiently.
#
# **`Main Uses of Docker`**
# Docker is primarily used to build, run, and deploy applications in a consistent, isolated, and scalable environment.
#
# `Problem Before Docker`
# When developing an application locally, everything may work fine. However, once the application is deployed to a cloud environment, issues arise, such as:
#
# - Compatibility: The application might rely on specific libraries, software versions, or dependencies that differ between the local development machine and the cloud system.
# - Miscommunication between Development and Deployment Teams: Differences in environments (local vs. cloud) lead to bugs or failure in deployment.
#
# **`Solution with Docker`**
#
# 1. Virtualization (VMs):
#    - Traditional virtualization involves running multiple operating systems (OS) in separate virtual machines (VMs), each with its own full OS. While VMs provide isolation, they require a lot of resources, as each VM includes its own OS.
#
# 2. Containerization (Docker):
#    - Docker uses the host OS, so it doesn't require a full OS for each container, which makes it much more lightweight and faster than traditional VMs. Containers share the host OS's kernel but run applications in isolated environments.
#    - This allows applications to run consistently across different environments (local, development, production) without worrying about dependency or compatibility issues.
#
# - Docker improves application portability and efficiency by using containerization instead of heavy virtual machines. It ensures applications work seamlessly across all environments and eliminates compatibility problems during deployment.
#
#
# **`Port Mapping`**
# - Since apps running inside containers are isolated machines. In order to access those applications we need to map host IP with container IP
# - `5000:5000 == host:container`
#
#
# **`Practical`**
# - For testing, We can create a flask app and run that app inside docker container
# - app.py inside docker_test folder
# - write a dockerfile to create a docker image for this app & run it inside container
# - perform port mapping so that we can access it on host browser

# %% [markdown]
# #### Difference b/w docker image & docker containers
#
# - `Docker image` is a blueprint or a template that contains all the dependencies, libraries, and configurations required to run an application. It is a read-only snapshot of the application and its environment
#
# - `Docker container` is a running instance of a Docker image. It is an environment where the application is executed. A container includes the application and its environment, but it also includes writable layers that store any changes (like logs, temporary data, or application state).
#
# - `docker image is the application and its dependencies & docker container is the running instance of that image`

# %% [markdown]
# #### 3 ways to create docker image
#
# 1. create image using dockerfile: `check docker_test folder`
# 2. pull from dockerhub
# 3. create image from docker container

# %% [markdown]
# ##### 2. pull from dockerhub
#
# 1. pull from dockerhub: `docker pull ubuntu`
# 2. `docker images` to check if ubuntu image is successfully pulled
# 3. run ubuntu image inside container: `docker run -it ubuntu /bin/bash` (-it means interactive mode & terminal mode)
#     - `docker run -it ubuntu /bin/bash` this command will check if ubuntu image is already pulled & run it if not then download that image & then run it, so we can skip pull command
# 4. now since we are inside the terminal of ubuntu, type `ls` to check the folders inside ubuntu image
#
# ![image.png](attachment:image.png)
#
# - `delete all image & container in 1 command`
# - docker system prune -a --volumes -f

# %% [markdown]
# ### ML Project

# %% [markdown]
# - End to end house price prediction project
# - Stages: Build --> Test (Unit & Int) --> Deliver (Docker) --> Deployment (CI/CD) --> Monitor --> Retraining (CT)
#
# **Project Flow**
# - We will build the project using `python`
# - Manage the source code using `Git` and save the code on central repository `GitHub`
# - During Continous Integration (CI), I will automate tests (unit & int) using `tox` on `Github Action Server`
# - We will create image of the project using `docker` and deliver the project: Continous Delivery (CD)
# - We can `deploy the docker image` on cloud aws/azure etc: Continous Deployment (CD)
# - `Evidently.AI` to monitor the project
# - `Airflow` to schedule continous training (CT)
#
# **Additional Tools**
# - Data management: `DVC`
# - Experiment Tracking: `MLFlow`
# - Model Registry: `Dagshub/BentoML`

# %% [markdown]
# ### Steps
#
# 1. Write pyproject.toml & setup.py code
# 2. Create init_setup.sh script to create venv, install requirements & activate environment
# 3. If not done in above step, install requirements_dev, This will create a package of the project with metadata using info in setup.py file
#
#     ![image.png](attachment:image.png)
#
# 4. Build temporary ml code on experiments.ipynb file, or export code files in experiments folder
# 5. Perform data assesment, cleaning, eda, model building to gain understanding of how project will proceed because it will be easier for us to convert this code into `modular coding`
# 6. All the modular coding related to the project will be done under `src` folder
# 7. Write code for `exception & logging`, Both folder should have __init__.py file
# 8. Write template code for `data ingestion, cleaning, transformation, evaluation & trainer`
# 9. We need to create 2 pipelines
#     1. training pipeline (data ingestion, transformation, model trainer & evaluation)
#     2. prediction (bulk/single value) pipeline (data transformation, prediction)
# 10. Use utility.py to define helping methods
# 11. After training pipeline, test if its able to perform, ingestion, cleaning, transformation, training, saving logs, preprocessor.pkl, model.pkl, saving logs etc
# 12. Write 'prediction pipeline':
#     - We need data to predict
#     - Bulk or Single row
#     - Pass data to preprocessor to apply transformation
#     - Pass transformed data to model
#     - Prediction
#     - Evaluation: Compare actual value with predicted value
# 13. Create flask app.py and index.html to check predictions

# %% [markdown]
# ### `MLFlow`
#
# - mlflow is mainly used for experiments tracking on multiple models & params
# - use "mlflow ui" command to visualize the params
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### `DVC: Data Versioning Control`
#
# - We can version control & manage the data same as what we do for source code using Git & Github
# - to initialize dvc: 'dvc init', It willl create 2 files .dvc & .dvcignore same as in git
# - when you run 'git status' after dvc init, you will see that all dvc files created by dvc init are automatically added to staging area
#
#     ![image.png](attachment:image.png)
#
# - run: 'dvc add data/test_data.csv' this will create a new file 'test_data.csv.dvc' and update test_data.csv in gitignore file inside data folder
#
#     ![image-2.png](attachment:image-2.png)
#
# - test_data.csv.dvc file has metadata about the test_data.csv file
# - update test_data.csv in gitignore file inside data folder since we never use git for data management bcoz of storage size, conflict resolution complexity etc
# - `how dvc tracks data?`: when we make changes to data & execute 'dvc add data/data.csv', or data changed then metdata about that file will be changed which now represents new version of the data and data version will also be saved.
# - using Git, we can track the dvc file for the data.
# - using git checkout and dvc checkout, we can access previous version of the data
#
#     ![image-3.png](attachment:image-3.png)
#
# - Along with data versioning we can also do `pipeline versioning/reproducibility` using dvc by writing configuration in dvc.yaml
# - dvc repro
#
#     ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ### `AirFlow`
#
# - We can containerize the complete application using docker
# - Using Airflow, we can perform Continous Training (CT)
